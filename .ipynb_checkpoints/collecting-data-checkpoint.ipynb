# %% [markdown]
# # Belorussian writers

# %% [markdown]
# We are going to look through all authors at https://www.livelib.ru/authors/belorussian and analyze their tags. For example, here:![image.png](attachment:image.png)
#
# we can see such tags as _poetry, belorussian language, modern literature_.
#
# We'd like to find out which tags are the most common and find some correlations. Is it true that modern authors write more prose than poetry? Let's find out.

# %% [markdown]
# ## Collecting data

# %% [markdown]
# First, we need to parse the tags from the pages of the site.

# %%
from bs4 import BeautifulSoup
import urllib

# %%
req = urllib.request.urlopen('https://www.livelib.ru/authors/belorussian')
text = req.read().decode()

soup = BeautifulSoup(text, 'lxml')

# %%
s.string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-97ab5b1bb379> in <module>
# ----> 1 s.string
#
# NameError: name 's' is not defined
